# %% [markdown]
# # Metadata Processing

# %% [markdown]
# ## A. Load in all all metadata and related files

# %%
import metadata_processing_utils as mpu
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from IPython.display import display, Markdown

# %%
# Read in various meta data files 
assay_df = pd.read_csv('/tscc/nfs/home/aopatel/SEA_AD_SNRNASEQ_MTG/SEA-AD_assay_snRNAseq_metadata.csv') # Change for ATAC 1/2
biospec_df = pd.read_csv('/tscc/nfs/home/aopatel/SEA_AD_SNRNASEQ_MTG/SEA-AD_biospecimen_metadata.csv')
indiv_df = pd.read_csv('/tscc/nfs/home/aopatel/SEA_AD_SNRNASEQ_MTG/SEA-AD_individual_metadata.csv')
cps = pd.read_csv('donor_scores.csv')
synapse_query_df = pd.read_csv('/tscc/lustre/ddn/scratch/aopatel/synapse_manifest/mtg_SYNAPSE_TABLE_QUERY_161185670.csv')


diagnoses = [
    "Alzheimers disease",
    "Pathology Control",
    "Neurotypical"]

# %% [markdown]
# ## B. Build metadata

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Build general metadata file for all brain regions
#
# </div>

# %%
meta_data=mpu.meta_data_builder(assay_df,biospec_df,indiv_df,cps, diagnoses, assay='scrnaSeq')

# %% [markdown]
# ## C. Build brain region specific metadata file for query construction

# %% [markdown]
# <div class="alert alert-block alert-info">
#   <b>Please choose one of the below:</b><br>
#   middle temporal gyrus<br>
#   dorsolateral prefrontal cortex<br>
#   medial entorhinal cortex<br>
#   primary visual cortex<br>
#   superior temporal gyrus
# </div>

# %%
# Select desired tissue
tissue='middle temporal gyrus'

brain_region_specific_meta=mpu.brain_region_specific_meta_builder(meta_data, tissue, synapse_query_df)

# %%
brain_region_specific_meta

# %%
#### Check PMI distribution
mpu.plot_pmi_distribution(brain_region_specific_meta)

# %% [markdown]
# ## D. Save brain region specific metadata file

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Save the final metadata file
#
# </div>

# %%
brain_region_specific_meta.to_csv('mtg_meta_data.csv', index=False) # Change file name for correct brain region
